# %% [markdown]
# ## OpenSooq scraping

# %% [markdown]
# ## Import Required Libraries

# %%
import requests
from bs4 import BeautifulSoup
import time
import re
import pandas as pd

# %% [markdown]
# ## Configuration Setup

# %%
# Base URL of the property listings
base_url = 'https://om.opensooq.com/en/property/property-for-sale'

# Headers to mimic a browser request
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
}

# Output filename for CSV
output_filename = 'opensooq_properties.csv'

# %% [markdown]
# ## Data Extraction Function

# %%
def extract_property_data(listing):
    """Extract property details from a single listing card"""
    # Extract title
    title_elem = listing.find('h2')
    title = title_elem.text.strip() if title_elem else None
    
    # Extract price (usually the last line in the card)
    card_text = listing.get_text(separator='\n', strip=True)
    lines = [line.strip() for line in card_text.split('\n') if line.strip()]
    price = lines[-1] if lines else None
    
    # Extract location (usually 2 lines before "Chat")
    location = None
    for i, line in enumerate(lines):
        if 'Chat' in line and i >= 2:
            location = f"{lines[i-2]}, {lines[i-1]}"
            break
    
    # Extract size (from Surface Area)
    size = None
    p_tag = listing.find('p')
    if p_tag:
        match = re.search(r'Surface\s*Area:\s*([0-9,]+)\s*m2', p_tag.text)
        if match:
            size = match.group(1).replace(',', '') + ' m²'
    
    # Extract link
    relative_link = listing.get('href', '')
    link = f"https://om.opensooq.com{relative_link}" if relative_link else None
    
    return {
        "source": "OpenSooq",
        "title": title,
        "price": price,
        "location": location,
        "size": size,
        "listing_type": "Property for Sale",
        "link": link
    }

# %% [markdown]
# ## Pagination Handling

# %%
def handle_pagination(soup, current_url):
    """Handle pagination and return next page URL or None if no more pages"""
    next_page_anchor = soup.find('a', attrs={'data-id': 'nextPageArrow'})
    if not next_page_anchor:
        print("No next page found. Done scraping.")
        return None
    
    next_page_relative_url = next_page_anchor.get('href', '')
    if not next_page_relative_url:
        print("No valid next page URL. Stopping.")
        return None
    
    new_url = f"https://om.opensooq.com{next_page_relative_url}"
    
    # Prevent infinite loop if same page repeats
    if new_url == current_url:
        print("Next page URL is same as current. Stopping.")
        return None
    
    return new_url

# %% [markdown]
# ## Main Scraping Function

# %%
def scrape_opensooq_properties():
    """Main function to scrape property listings"""
    opensooq_data = []
    current_page_url = base_url
    
    print("Starting OpenSooq Oman property scraping...")
    
    while True:
        print(f"Scraping page: {current_page_url}")
        
        try:
            response = requests.get(current_page_url, headers=headers)
            response.raise_for_status()
        except requests.exceptions.RequestException as e:
            print(f"Error fetching page {current_page_url}: {e}")
            break
        
        soup = BeautifulSoup(response.content, 'html.parser')
        listings = soup.find_all('a', class_=lambda x: x and 'postListItemData' in x)
        
        if not listings:
            print("No listings found on page. Stopping.")
            break
        
        for listing in listings:
            property_data = extract_property_data(listing)
            opensooq_data.append(property_data)
        
        current_page_url = handle_pagination(soup, current_page_url)
        if not current_page_url:
            break
        
        time.sleep(1)  # Polite delay between requests
    
    return opensooq_data

# %% [markdown]
# ## Execute Scraping and Save Results

# %%
# Execute scraping
property_data = scrape_opensooq_properties()

# Convert to DataFrame
df = pd.DataFrame(property_data)

# Display first 5 rows
df.head()
# Out:
# Starting OpenSooq Oman property scraping...
# Scraping page: https://om.opensooq.com/en/property/property-for-sale
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=2
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=3
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=4
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=5
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=6
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=7
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=8
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=9
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=10
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=11
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=12
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=13
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=14
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=15
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=16
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=17
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=18
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=19
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=20
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=21
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=22
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=23
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=24
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=25
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=26
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=27
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=28
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=29
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=30
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=31
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=32
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=33
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=34
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=35
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=36
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=37
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=38
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=39
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=40
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=41
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=42
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=43
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=44
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=45
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=46
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=47
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=48
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=49
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=50
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=51
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=52
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=53
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=54
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=55
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=56
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=57
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=58
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=59
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=60
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=61
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=62
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=63
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=64
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=65
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=66
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=67
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=68
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=69
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=70
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=71
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=72
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=73
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=74
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=75
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=76
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=77
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=78
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=79
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=80
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=81
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=82
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=83
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=84
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=85
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=86
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=87
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=88
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=89
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=90
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=91
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=92
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=93
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=94
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=95
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=96
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=97
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=98
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=99
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=100
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=101
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=102
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=103
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=104
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=105
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=106
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=107
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=108
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=109
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=110
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=111
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=112
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=113
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=114
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=115
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=116
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=117
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=118
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=119
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=120
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=121
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=122
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=123
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=124
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=125
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=126
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=127
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=128
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=129
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=130
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=131
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=132
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=133
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=134
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=135
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=136
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=137
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=138
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=139
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=140
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=141
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=142
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=143
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=144
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=145
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=146
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=147
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=148
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=149
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=150
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=151
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=152
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=153
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=154
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=155
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=156
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=157
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=158
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=159
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=160
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=161
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=162
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=163
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=164
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=165
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=166
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=167
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=168
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=169
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=170
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=171
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=172
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=173
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=174
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=175
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=176
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=177
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=178
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=179
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=180
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=181
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=182
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=183
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=184
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=185
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=186
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=187
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=188
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=189
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=190
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=191
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=192
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=193
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=194
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=195
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=196
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=197
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=198
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=199
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=200
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=201
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=202
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=203
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=204
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=205
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=206
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=207
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=208
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=209
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=210
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=211
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=212
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=213
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=214
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=215
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=216
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=217
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=218
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=219
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=220
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=221
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=222
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=223
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=224
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=225
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=226
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=227
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=228
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=229
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=230
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=231
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=232
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=233
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=234
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=235
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=236
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=237
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=238
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=239
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=240
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=241
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=242
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=243
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=244
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=245
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=246
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=247
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=248
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=249
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=250
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=251
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=252
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=253
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=254
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=255
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=256
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=257
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=258
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=259
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=260
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=261
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=262
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=263
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=264
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=265
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=266
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=267
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=268
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=269
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=270
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=271
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=272
# Scraping page: https://om.opensooq.com/en/property/property-for-sale?page=273
# No listings found on page. Stopping.
#      source                                              title        price  \
# 0  OpenSooq  118 m2 3 Bedrooms Apartments for Sale in Musca...   45,000 OMR
# 1  OpenSooq                  Building for Sale in Muscat Ghala  950,000 OMR
# 2  OpenSooq  77 m2 2 Bedrooms Apartments for Sale in Muscat...   31,000 OMR
# 3  OpenSooq  52 m2 Studio Apartments for Sale in Muscat Al ...   29,000 OMR
# 4  OpenSooq  320 m2 5 Bedrooms Villa for Sale in Muscat Qur...  100,000 OMR
#
#                  location     size       listing_type  \
# 0      , Bosher, 964439XX   118 m²  Property for Sale
# 1       , Ghala, 924618XX  2200 m²  Property for Sale
# 2      , Azaiba, 715560XX    77 m²  Property for Sale
# 3  , Al Mawaleh, 964439XX    52 m²  Property for Sale
# 4     , Quriyat, 985055XX   320 m²  Property for Sale
#
#                                           link
# 0  https://om.opensooq.com/en/search/264252105
# 1  https://om.opensooq.com/en/search/253985415
# 2  https://om.opensooq.com/en/search/266186647
# 3  https://om.opensooq.com/en/search/265496647
# 4  https://om.opensooq.com/en/search/266519035

# %% [markdown]
# ## Save Scraping Data into CSV File

# %%
# Save to CSV
df.to_csv(output_filename, index=False)
print(f"Data successfully saved to {output_filename}")

# Show summary
print(f"\nScraped {len(df)} properties")
df.info()
# Out:
# Data successfully saved to opensooq_properties.csv
#
# Scraped 8155 properties
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8155 entries, 0 to 8154
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   source        8155 non-null   object
#  1   title         8155 non-null   object
#  2   price         8155 non-null   object
#  3   location      8148 non-null   object
#  4   size          3943 non-null   object
#  5   listing_type  8155 non-null   object
#  6   link          8155 non-null   object
# dtypes: object(7)
# memory usage: 446.1+ KB
